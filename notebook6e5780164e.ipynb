# %%
# !git clone https://github.com/srikanthp1/S16.git
# Out:
# Cloning into 'S16'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 25 (delta 10), reused 18 (delta 6), pack-reused 0
# Receiving objects: 100% (25/25), 11.13 KiB | 11.13 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# %cd S16
# Out:
# /kaggle/working/S16/S16/S16/S16

# %%
# !ls
# Out:
# README.md  config.py  dataset.py  model.py  notebook.ipynb  train.py

# %%
# !python train.py
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using device: cuda
# [00:00:00] Pre-processing sequences                 ████████ 0        /        0
# [00:00:00] Pre-processing sequences                 ████████ 1000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 2000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 3000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 4000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 5000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 6000     /        0
# [00:00:00] Pre-processing sequences                 ████████ 7000     /        0
# ...
